# %%
import matplotlib.pyplot as plt
import pandas as pd, json


#data = [31.64,31.63,31.96,31.04,31.08,31.76,31.35,31.32,31.79,31.67, 
#        31.69,31.15,31.04,31.3,31.64,31.02,31.11,31.17,31.59,31.25,
#        31.87,31.58,31.68,31.45,31.03,31.65,31.82,31.7,31.67,31.7,
#        31.88,31.93,31.03,31.67,31.9,31.96,31.94,31.99,31.89,31.74,
#        31.69,31.78,31.19,31.53,31.57,31.12,31.06,31.73,31.42,31.47]

#data = pd.read_fwf('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Fog/log-karaf/Log-sc02-temperatureSensor-2019-01-12T15:38:26.427.txt')
data = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Fog/log-karaf/Log-sc02-temperatureSensor-2019-01-12T15:38:26.427.txt','r')
newData = []


for line in data:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newData.append(float(value))
            #print(newData)

dataframe = pd.DataFrame(newData, columns=['Temperature'])
dataframe.plot(label="velocidade")
plt.xlabel('Amount of Data')
plt.ylabel('Temperature')
#plt.grid(True)
#plt.plot(data)
#plt.xlim(0, 50)
plt.ylim(26, 35);
plt.title("Data Stream of Temperature in Fog")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd, json


#data = [31.64,31.63,31.96,31.04,31.08,31.76,31.35,31.32,31.79,31.67, 
#        31.69,31.15,31.04,31.3,31.64,31.02,31.11,31.17,31.59,31.25,
#        31.87,31.58,31.68,31.45,31.03,31.65,31.82,31.7,31.67,31.7,
#        31.88,31.93,31.03,31.67,31.9,31.96,31.94,31.99,31.89,31.74,
#        31.69,31.78,31.19,31.53,31.57,31.12,31.06,31.73,31.42,31.47]

#data = pd.read_fwf('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Fog/log-karaf/Log-sc02-temperatureSensor-2019-01-12T15:38:26.427.txt')
data = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Fog/log-karaf/Log-sc02-luminositySensor-2019-01-12T15:38:27.289.txt','r')
newData = []


for line in data:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newData.append(float(value))
            #print(newData)

dataframe = pd.DataFrame(newData, columns=['Luminosity'])
dataframe.plot()
plt.xlabel('Amount of Data')
plt.ylabel('Luminosity')
#plt.grid(True)
#plt.plot(data)
#plt.xlim(0, 50)
#plt.ylim(26, 35);
plt.title("Data Stream Luminosity Sensor Fog Cusum")
plt.show()

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd, json
 
# Data
# df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21) })
dataFog = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Fog/log-karaf/Log-sc02-temperatureSensor-2019-01-12T15:38:26.427.txt','r')
dataCloud = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Cloud/kafka-python/Log-sc02-temperatureSensor-2019-01-12 04:08:33.394222.txt','r')
newDataFog = []
newDataCloud = []

for line in dataFog:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newDataFog.append(float(value))
            #print(newData)

for line in dataCloud:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newDataCloud.append(float(value))
            #print(newDataCloud)            
            
            
            
df=pd.DataFrame({'y2':newDataCloud})
    
    
# multiple line plot
#plt.plot(data=newDataFog, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot('y2', data=df, marker='', color='blue', linewidth=2, label='Temperature')
#plt.plot('y1', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.title("Data Stream of Temperature in Cloud with Cusum Processing")
plt.xlabel('Amount of Data')
plt.ylabel('Temperature')
plt.legend()

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd, json
 
# Data
# df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21) })
#dataFog = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Fog/log-karaf/Log-sc02-temperatureSensor-2019-01-12T15:38:26.427.txt','r')
dataCloud = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Cloud/kafka-python/Log-sc02-luminositySensor-2019-01-12 04:08:33.395049.txt','r')
#newDataFog = []
newDataCloud = []

"""
for line in dataFog:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newDataFog.append(float(value))
            #print(newData)
"""

for line in dataCloud:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newDataCloud.append(float(value))
            #print(newDataCloud)            
            
            
            
df=pd.DataFrame({'y2':newDataCloud})
    
    
# multiple line plot
#plt.plot(data=newDataFog, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot('y2', data=df, marker='', color='blue', linewidth=2, label='Luminosity')
#plt.plot('y1', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.title("Data Stream Luminosity Sensor Cloud Cusum")
plt.xlabel('Amount of Data')
plt.ylabel('Luminosity')
plt.legend()

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd, json
 
# Data
# df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21) })
dataFog = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Fog/log-karaf/Log-sc02-temperatureSensor-2019-01-12T15:38:26.427.txt','r')
dataCloud = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Cloud/kafka-python/Log-sc02-temperatureSensor-2019-01-12 04:08:33.394222.txt','r')
newDataFog = []
newDataCloud = []

for line in dataFog:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newDataFog.append(float(value))
            #print(newData)

for line in dataCloud:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newDataCloud.append(float(value))
            #print(newDataCloud)            
            
            
print("x")
# Out:
# x

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple


n_groups = 5

means_5 = (6, 6, 7, 6, 7)
#std_men = (2, 3, 4, 1, 2)

means_10 = (12, 13, 14, 11, 13)
#std_women = (3, 5, 2, 3, 3)

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.35

opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index, means_5, bar_width,
                alpha=opacity, color='b', error_kw=error_config,
                label='5 sensors')

rects2 = ax.bar(index + bar_width, means_10, bar_width,
                alpha=opacity, color='r', error_kw=error_config,
                label='10 sensors')

#ax.set_xlabel('Group')
ax.set_ylabel('Throughput')
ax.set_title('Scores by group and gender')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('Dust', 'Humidity', 'Luminosity', 'Sound', 'Temperature'))
ax.legend()

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
# np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
sensors = ('Dust', 'Humidity', 'Luminosity', 'Sound', 'Temperature')
y_pos = np.arange(len(sensors))
#performance = 3 + 10 * np.random.rand(len(people))
#error = np.random.rand(len(people))

error = (0.1, 0.3, 0.2, 0.1, 0.2)
means_5 = (6, 6, 7, 6, 7)

ax.barh(y_pos, means_5, xerr=error, align='center',
        color='#6495ED', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(sensors)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Throughput/min')
ax.set_ylabel('1 sensor of each')
ax.set_title('Throughput Receive of FoT-StreamGateway with 5 sensors')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
# np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
sensors = ('Dust', 'Humidity', 'Luminosity', 'Sound', 'Temperature')
y_pos = np.arange(len(sensors))
#performance = 3 + 10 * np.random.rand(len(people))
#error = np.random.rand(len(people))

error = (0.1, 0.3, 0.2, 0.1, 0.2)
means_10 = (12, 13, 14, 11, 13)

ax.barh(y_pos, means_10, xerr=error, align='center',
        color='#6495ED', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(sensors)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Throughput/min')
ax.set_ylabel('2 sensor of each')
ax.set_title('Throughput Receive of FoT-StreamGateway with 10 sensors')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd, json


"""
dataFog = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Fog/log-karaf/Log-sc02-temperatureSensor-2019-01-12T15:38:26.427.txt','r')
newDataFog = []
cumulativeSize = 0 

for line in dataFog:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        size = logDevice['WindowSize']    
        cumulativeSize = cumulativeSize + size

print(cumulativeSize)
"""

dataCloud = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Cloud/kafka-python/Log-sc02-temperatureSensor-2019-01-12 04:08:33.394222.txt','r')
newDataCloud = []
cumulativeSize = 0 

for line in dataCloud:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        size = logDevice['WindowSize']
        cumulativeSize = cumulativeSize + size

#print(cumulativeSize)

n_groups = 5

#means_Fog = (67343, 68915, 67902, 67834, 69937)
#std_men = (2, 3, 4, 1, 2)
means_Fog = (67.343, 68.915, 67.902, 67.834, 69.937)


#means_Cloud = (16251, 4351, 8116, 6616, 1603)
#std_women = (3, 5, 2, 3, 3)
means_Cloud = (16.251, 4.351, 8.116, 6.616, 1.603)

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.35

opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index, means_Fog, bar_width,
                alpha=opacity, color='b', error_kw=error_config,
                label='Number of KB Fog')

rects2 = ax.bar(index + bar_width, means_Cloud, bar_width,
                alpha=opacity, color='r', error_kw=error_config,
                label='Number of KB Cloud')

#ax.set_xlabel('Group')
ax.set_ylabel('Number of KB')
ax.set_title('Number of KB processed and trafficked with CUSUM')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('Dust', 'Humidity', 'Luminosity', 'Sound', 'Temperature'))
ax.legend()

plt.ylim(0, 85);

fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n_groups = 5

#means_Fog = (67343, 68915, 67902, 67834, 69937)
#std_men = (2, 3, 4, 1, 2)
means_Fog = (79.34, 81.41, 82.42, 80.83, 77.37)


#means_Cloud = (16251, 4351, 8116, 6616, 1603)
#std_women = (3, 5, 2, 3, 3)
means_Cloud = (81.25, 83.4, 84.11, 81.61, 79.60)

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.35

opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index, means_Fog, bar_width,
                alpha=opacity, color='b', error_kw=error_config,
                label='Delay Processing Fog')

rects2 = ax.bar(index + bar_width, means_Cloud, bar_width,
                alpha=opacity, color='r', error_kw=error_config,
                label='Delay Processing Fog and Cloud')

#ax.set_xlabel('Group')
ax.set_ylabel('Delay/s')
ax.set_title('Window Delay Processing in FoT-StreamGateway from Fog to Cloud')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('Dust', 'Humidity', 'Luminosity', 'Sound', 'Temperature'))
ax.legend()

plt.ylim(0, 105);

fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd, json


"""
dataFog = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/Haar-Wavelets/17-01-2019/Fog/log-karaf/Log-sc02-temperatureSensor-2019-01-17T04:35:00.528.txt','r')
newDataFog = []
cumulativeSize = 0 

for line in dataFog:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        size = logDevice['WindowSize']
        cumulativeSize = cumulativeSize + size

print(cumulativeSize)


dataCloud = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/Haar-Wavelets/17-01-2019/Cloud/kafka-python/Log-sc02-temperatureSensor-2019-01-17 04:32:28.909191.txt','r')
newDataCloud = []
cumulativeSize = 0 

for line in dataCloud:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        size = logDevice['WindowSize']
        cumulativeSize = cumulativeSize + size

print(cumulativeSize)
"""

n_groups = 5

#means_Fog = (67343, 68915, 67902, 67834, 69937)
#std_men = (2, 3, 4, 1, 2)
means_Fog = (41.914, 42.698, 42.065, 42.154, 43.358)


#means_Cloud = (16251, 4351, 8116, 6616, 1603)
#std_women = (3, 5, 2, 3, 3)
means_Cloud = (8.431, 2.654, 5.863, 2.023, 1.454)

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.35

opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index, means_Fog, bar_width,
                alpha=opacity, color='b', error_kw=error_config,
                label='Number of KB Fog')

rects2 = ax.bar(index + bar_width, means_Cloud, bar_width,
                alpha=opacity, color='r', error_kw=error_config,
                label='Number of KB Cloud')

#ax.set_xlabel('Group')
ax.set_ylabel('Number of KB')
ax.set_title('Number of KB processed and trafficked with Haar and CUSUM')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('Dust', 'Humidity', 'Luminosity', 'Sound', 'Temperature'))
ax.legend()

plt.ylim(0, 55);

fig.tight_layout()
plt.show()

# %%
#Primeiramente importamos as libs
import numpy as np
import matplotlib.pyplot as plt

# Um gráfico com a renda média por faixa etária será nosso Hello World, vamos definir alguns valores fictícios
Sensors = ['Dust', 'Humidity', 'Luminosity', 'Sound', 'Temperature']
delay = [15.33, 17.3, 13.1, 19.2, 12.22]

"""
    Chamamos o método bar que criará o gráfico de barra 
    passamos os argumentos que são: 
        - faixaEtaria como eixo x 
        - renda como eixo y
        - color para as cores das barras como red ( vermelho )
"""
plt.bar(Sensors, delay, color="#00BFFF")

# Aqui definimos as legendas de cada barra no eixo X
plt.xticks(Sensors)

# A label para o eixo Y
plt.ylabel('Delay Processing/ms')

# A label para o eixo X
#plt.xlabel('Faixa etaria (anos)')

# O título do gráfico
plt.title('Haar and Cusum Delay Processing in FoT-StreamGateway')
 
# Chamamos o método show() para mostrar o gráfico na tela
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd, json


#data = [31.64,31.63,31.96,31.04,31.08,31.76,31.35,31.32,31.79,31.67, 
#        31.69,31.15,31.04,31.3,31.64,31.02,31.11,31.17,31.59,31.25,
#        31.87,31.58,31.68,31.45,31.03,31.65,31.82,31.7,31.67,31.7,
#        31.88,31.93,31.03,31.67,31.9,31.96,31.94,31.99,31.89,31.74,
#        31.69,31.78,31.19,31.53,31.57,31.12,31.06,31.73,31.42,31.47]

#data = pd.read_fwf('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Fog/log-karaf/Log-sc02-temperatureSensor-2019-01-12T15:38:26.427.txt')
data = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/Haar-Wavelets/17-01-2019/Fog/log-karaf/Log-sc02-temperatureSensor-2019-01-17T04:35:00.528.txt','r')
newData = []


for line in data:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newData.append(float(value))
            #print(newData)

dataframe = pd.DataFrame(newData, columns=['Temperature'])
dataframe.plot()
plt.xlabel('Amount of Data')
plt.ylabel('Temperature')
#plt.grid(True)
#plt.plot(data)
#plt.xlim(0, 50)
plt.ylim(26, 35);
plt.title("Data Stream of Temperature in Fog with Haar Processing")
plt.show()

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd, json
 
# Data
# df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21) })
#dataFog = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Fog/log-karaf/Log-sc02-temperatureSensor-2019-01-12T15:38:26.427.txt','r')
dataCloud = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/Haar-Wavelets/17-01-2019/Cloud/kafka-python/Log-sc02-temperatureSensor-2019-01-17 04:32:28.909191.txt','r')
#newDataFog = []
newDataCloud = []

"""
for line in dataFog:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newDataFog.append(float(value))
            #print(newData)
"""

for line in dataCloud:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newDataCloud.append(float(value))
            #print(newDataCloud)            
            
            
            
df=pd.DataFrame({'y2':newDataCloud})
    
    
# multiple line plot
#plt.plot(data=newDataFog, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot('y2', data=df, marker='', color='blue', linewidth=2, label='Temperature')
#plt.plot('y1', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.title("Data Stream of Temperature in Cloud with Cusum Processing")
plt.xlabel('Amount of Data')
plt.ylabel('Temperature')
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd, json


#data = [31.64,31.63,31.96,31.04,31.08,31.76,31.35,31.32,31.79,31.67, 
#        31.69,31.15,31.04,31.3,31.64,31.02,31.11,31.17,31.59,31.25,
#        31.87,31.58,31.68,31.45,31.03,31.65,31.82,31.7,31.67,31.7,
#        31.88,31.93,31.03,31.67,31.9,31.96,31.94,31.99,31.89,31.74,
#        31.69,31.78,31.19,31.53,31.57,31.12,31.06,31.73,31.42,31.47]

#data = pd.read_fwf('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Fog/log-karaf/Log-sc02-temperatureSensor-2019-01-12T15:38:26.427.txt')
data = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/Haar-Wavelets/17-01-2019/Fog/log-karaf/Log-sc02-luminositySensor-2019-01-17T04:35:01.620.txt','r')
newData = []


for line in data:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newData.append(float(value))
            #print(newData)

dataframe = pd.DataFrame(newData, columns=['Luminosity'])
dataframe.plot()
plt.xlabel('Amount of Data')
plt.ylabel('Luminosity')
#plt.grid(True)
#plt.plot(data)
#plt.xlim(0, 50)
#plt.ylim(26, 35);
plt.title("Data Stream Luminosity Sensor Fog Haar and Cusum")
plt.show()

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd, json
 
# Data
# df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21) })
#dataFog = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/12-01-2019/Fog/log-karaf/Log-sc02-temperatureSensor-2019-01-12T15:38:26.427.txt','r')
dataCloud = open('/home/brenno/Documentos/Simulations-Stream/Cusum-Rasp/5-sensors/Haar-Wavelets/17-01-2019/Cloud/kafka-python/Log-sc02-luminositySensor-2019-01-17 04:32:28.910355.txt','r')
#newDataFog = []
newDataCloud = []

"""
for line in dataFog:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newDataFog.append(float(value))
            #print(newData)
"""

for line in dataCloud:
    logDevice = json.loads(line)
    if "valueSensor" in logDevice:
        for value in logDevice['valueSensor']:    
            newDataCloud.append(float(value))
            #print(newDataCloud)            
            
            
            
df=pd.DataFrame({'y2':newDataCloud})
    
    
# multiple line plot
#plt.plot(data=newDataFog, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot('y2', data=df, marker='', color='blue', linewidth=2, label='Luminosity')
#plt.plot('y1', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.title("Data Stream Luminosity Sensor Cloud Haar and Cusum")
plt.xlabel('Amount of Data')
plt.ylabel('Luminosity')
plt.legend()
